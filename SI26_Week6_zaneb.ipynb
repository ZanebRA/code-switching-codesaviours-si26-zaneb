# %% [markdown]
# <a href="https://colab.research.google.com/github/ZanebRA/code-switching-codesaviours-si26-zaneb/blob/main/SI26_Week6_zaneb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = [
    {
        "sentence": "Aaj ka din bohot busy tha",
        "words": ["Aaj", "ka", "din", "bohot", "busy", "tha"],
        "labels": ["URD", "URD", "URD", "URD", "ENG", "URD"]
    },
    {
        "sentence": "Yaar seriously I can not even right now",
        "words": ["Yaar", "seriously", "I", "can", "not", "even", "right", "now"],
        "labels": ["URD", "ENG", "ENG", "ENG", "ENG", "ENG", "ENG", "ENG"]
    },
    {
    "sentence": "Bhaai mera ChatGPT pagal hogeya hai",
    "words": ["Bhaai", "mera", "ChatGPT", "pagal", "hogeya", "hai"],
    "labels": ["URD", "URD", "ENG", "URD", "URD", "URD"]
},
{
    "sentence": "Society page ki profile ky liye",
    "words": ["Society", "page", "ki", "profile", "ky", "liye"],
    "labels": ["ENG", "ENG", "URD", "ENG", "URD", "URD"]
},
{
    "sentence": "Muje smj aai hotiii to mein depression mein hoti",
    "words": ["Muje", "smj", "aai", "hotiii", "to", "mein", "depression", "mein", "hoti"],
    "labels": ["URD", "URD", "URD", "URD", "URD", "URD", "ENG", "URD", "URD"]
},
{
    "sentence": "Comment kro post par",
    "words": ["Comment", "kro", "post", "par"],
    "labels": ["ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Comment kis cheez k baray mai",
    "words": ["Comment", "kis", "cheez", "k", "baray", "mai"],
    "labels": ["ENG", "URD", "URD", "URD", "URD", "URD"]
},
{
    "sentence": "U guyz giving presentation on Saturday or Sunday",
    "words": ["U", "guyz", "giving", "presentation", "on", "Saturday", "or", "Sunday"],
    "labels": ["ENG", "ENG", "ENG", "ENG", "ENG", "ENG", "ENG", "ENG"]
},
{
    "sentence": "I will send yours babe",
    "words": ["I", "will", "send", "yours", "babe"],
    "labels": ["ENG", "ENG", "ENG", "ENG", "ENG"]
},
{
    "sentence": "Hum free nhi hain",
    "words": ["Hum", "free", "nhi", "hain"],
    "labels": ["URD", "ENG", "URD", "URD"]
},
{
    "sentence": "Apni koi random group photo share kr dain sb aik",
    "words": ["Apni", "koi", "random", "group", "photo", "share", "kr", "dain", "sb", "aik"],
    "labels": ["URD", "URD", "ENG", "ENG", "ENG", "ENG", "URD", "URD", "URD", "URD"]
},
{
    "sentence": "Sai ha boss",
    "words": ["Sai", "ha", "boss"],
    "labels": ["URD", "URD", "ENG"]
},

{
    "sentence": "Baji sending you and your loved ones my warmest wishes meri dost",
    "words": ["Baji", "sending", "you", "and", "your", "loved", "ones", "my", "warmest", "wishes", "meri", "dost"],
    "labels": ["URD", "ENG", "ENG", "ENG", "ENG", "ENG", "ENG", "ENG", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Lead generation ka Kitna experience",
    "words": ["Lead", "generation", "ka", "Kitna", "experience"],
    "labels": ["ENG", "ENG", "URD", "URD", "ENG"]
},
{
    "sentence": "Abhi soft form mai mujhy bhej do CamScanner se",
    "words": ["Abhi", "soft", "form", "mai", "mujhy", "bhej", "do", "CamScanner", "se"],
    "labels": ["URD", "ENG", "ENG", "URD", "URD", "URD", "URD", "ENG", "URD"]
},
{
    "sentence": "Submit krwane ke lie khud jana",
    "words": ["Submit", "krwane", "ke", "lie", "khud", "jana"],
    "labels": ["ENG", "URD", "URD", "URD", "URD", "URD"]
},
{
    "sentence": "Bs kuch nai chutti enjoys",
    "words": ["Bs", "kuch", "nai", "chutti", "enjoys"],
    "labels": ["URD", "URD", "URD", "URD", "ENG"]
},
{
    "sentence": "Because us pr real jobs hoti",
    "words": ["Because", "us", "pr", "real", "jobs", "hoti"],
    "labels": ["ENG", "URD", "URD", "ENG", "ENG", "URD"]
},
{
    "sentence": "Khana k document mai deti hun",
    "words": ["Khana", "k", "document", "mai", "deti", "hun"],
    "labels": ["URD", "URD", "ENG", "URD", "URD", "URD"]
},
{
    "sentence": "Laikin first is the last date registration ki",
    "words": ["Laikin", "first", "is", "the", "last", "date", "registration", "ki"],
    "labels": ["URD", "ENG", "ENG", "ENG", "ENG", "ENG", "ENG", "URD"]
},
{
    "sentence": "Funny horhy ho ap",
    "words": ["Funny", "horhy", "ho", "ap"],
    "labels": ["ENG", "URD", "URD", "URD"]
},
{
    "sentence": "Is se accuracy thik ho jay gi",
    "words": ["Is", "se", "accuracy", "thik", "ho", "jay", "gi"],
    "labels": ["URD", "URD", "ENG", "URD", "URD", "URD", "URD"]
},
    {
    "sentence": "Tickets bht expensive hain",
    "words": ["Tickets", "bht", "expensive", "hain"],
    "labels": ["ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Travelling for fun ya kaam k liye",
    "words": ["Travelling", "for", "fun", "ya", "kaam", "k", "liye"],
    "labels": ["ENG", "ENG", "ENG", "URD", "URD", "URD", "URD"]
},
{
    "sentence": "Mujhe Friday ko bhej rhe the",
    "words": ["Mujhe", "Friday", "ko", "bhej", "rhe", "the"],
    "labels": ["URD", "ENG", "URD", "URD", "URD", "URD"]
},
{
    "sentence": "Area manager aye thi meri shift 7 tak thi",
    "words": ["Area", "manager", "aye", "thi", "meri", "shift", "7", "tak", "thi"],
    "labels": ["ENG", "ENG", "URD", "URD", "URD", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Dusre store gai thi",
    "words": ["Dusre", "store", "gai", "thi"],
    "labels": ["URD", "ENG", "URD", "URD"]
},
{
    "sentence": "Aj mera driving test tha",
    "words": ["Aj", "mera", "driving", "test", "tha"],
    "labels": ["URD", "URD", "ENG", "ENG", "URD"]
},
{
    "sentence": "Mai British Columbia hon",
    "words": ["Mai", "British", "Columbia", "hon"],
    "labels": ["URD", "ENG", "ENG", "URD"]
},
{
    "sentence": "Final year project ka idea k baray mai puchna tha",
    "words": ["Final", "year", "project", "ka", "idea", "k", "baray", "mai", "puchna", "tha"],
    "labels": ["ENG", "ENG", "ENG", "URD", "ENG", "URD", "URD", "URD", "URD", "URD"]
},
{
    "sentence": "EAT AND READ HOTEL mai rukna hai",
    "words": ["EAT", "AND", "READ", "HOTEL", "mai", "rukna", "hai"],
    "labels": ["ENG", "ENG", "ENG", "ENG", "URD", "URD", "URD"]
},
{
    "sentence": "Sun drama yaad agaya",
    "words": ["Sun", "drama", "yaad", "agaya"],
    "labels": ["ENG", "ENG", "URD", "URD"]
},

  {
    "sentence": "Candles kyu jalai",
    "words": ["Candles", "kyu", "jalai"],
    "labels": ["ENG", "URD", "URD"]
},
{
    "sentence": "Bakwas movie",
    "words": ["Bakwas", "movie"],
    "labels": ["URD", "ENG"]
},
{
    "sentence": "Director ne film Banai",
    "words": ["Director", "ne", "film", "Banai"],
    "labels": ["ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Photo kyun lagayi ha poster par",
    "words": ["Photo", "kyun", "lagayi", "ha", "poster", "par"],
    "labels": ["ENG", "URD", "URD", "URD", "ENG", "URD"]
},
{
    "sentence": "Ahmed ki likhi hui stories",
    "words": ["Ahmed", "ki", "likhi", "hui", "stories"],
    "labels": ["ENG", "URD", "URD", "URD", "ENG"]
},
{
    "sentence": "I was laughing to hear maa g",
    "words": ["I", "was", "laughing", "to", "hear", "maa", "g"],
    "labels": ["ENG", "ENG", "ENG", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Acha part about Umera Ahmed writing Islam",
    "words": ["Acha", "part", "about", "Umera", "Ahmed", "writing", "Islam"],
    "labels": ["URD", "ENG", "ENG", "ENG", "ENG", "ENG", "ENG"]
},
{
    "sentence": "Monday Tuesday ko begum",
    "words": ["Monday", "Tuesday", "ko", "begum"],
    "labels": ["ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Taya jaan and tayi jaan of Anas from parallel universe yar ye",
    "words": ["Taya", "jaan", "and", "tayi", "jaan", "of", "Anas", "from", "parallel", "universe", "yar", "ye"],
    "labels": ["URD", "URD", "ENG", "URD", "URD", "ENG", "ENG", "ENG", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Kal office jana hai but mood nahi hai",
    "words": ["Kal", "office", "jana", "hai", "but", "mood", "nahi", "hai"],
    "labels": ["URD", "ENG", "URD", "URD", "ENG", "ENG", "URD", "URD"]
},
    {
    "sentence": "Assignment complete hogayi but review baqi hai",
    "words": ["Assignment", "complete", "hogayi", "but", "review", "baqi", "hai"],
    "labels": ["ENG", "ENG", "URD", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Mera laptop hang horha hai again",
    "words": ["Mera", "laptop", "hang", "horha", "hai", "again"],
    "labels": ["URD", "ENG", "ENG", "URD", "URD", "ENG"]
},
{
    "sentence": "Yaar meeting cancel hogayi",
    "words": ["Yaar", "meeting", "cancel", "hogayi"],
    "labels": ["URD", "ENG", "ENG", "URD"]
},
{
    "sentence": "Kal office ka schedule change hogaya",
    "words": ["Kal", "office", "ka", "schedule", "change", "hogaya"],
    "labels": ["URD", "ENG", "URD", "ENG", "ENG", "URD"]
},
{
    "sentence": "Presentation bohot achi thi honestly",
    "words": ["Presentation", "bohot", "achi", "thi", "honestly"],
    "labels": ["ENG", "URD", "URD", "URD", "ENG"]
},
{
    "sentence": "Class attend karlo warna attendance short hojayegi",
    "words": ["Class", "attend", "karlo", "warna", "attendance", "short", "hojayegi"],
    "labels": ["ENG", "ENG", "URD", "URD", "ENG", "ENG", "URD"]
},
{
    "sentence": "Mujhe email check karni hai",
    "words": ["Mujhe", "email", "check", "karni", "hai"],
    "labels": ["URD", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Teacher ne assignment upload kardiya",
    "words": ["Teacher", "ne", "assignment", "upload", "kardiya"],
    "labels": ["ENG", "URD", "ENG", "ENG", "URD"]
},
{
    "sentence": "Internet bohot slow chal raha hai",
    "words": ["Internet", "bohot", "slow", "chal", "raha", "hai"],
    "labels": ["ENG", "URD", "ENG", "URD", "URD", "URD"]
},
{
    "sentence": "Result kab announce hoga",
    "words": ["Result", "kab", "announce", "hoga"],
    "labels": ["ENG", "URD", "ENG", "URD"]
},
    {
    "sentence": "Aaj weather bohot amazing hai",
    "words": ["Aaj", "weather", "bohot", "amazing", "hai"],
    "labels": ["URD", "ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Meri file upload hogayi finally",
    "words": ["Meri", "file", "upload", "hogayi", "finally"],
    "labels": ["URD", "ENG", "ENG", "URD", "ENG"]
},
{
    "sentence": "Please mujhe notes send kar do",
    "words": ["Please", "mujhe", "notes", "send", "kar", "do"],
    "labels": ["ENG", "URD", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Kal quiz hai prepare rehna",
    "words": ["Kal", "quiz", "hai", "prepare", "rehna"],
    "labels": ["URD", "ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Project deadline bohot close hai",
    "words": ["Project", "deadline", "bohot", "close", "hai"],
    "labels": ["ENG", "ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Mujhe Zoom meeting join karni hai",
    "words": ["Mujhe", "Zoom", "meeting", "join", "karni", "hai"],
    "labels": ["URD", "ENG", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Ye idea really acha hai",
    "words": ["Ye", "idea", "really", "acha", "hai"],
    "labels": ["URD", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Aaj office mein workload zyada tha",
    "words": ["Aaj", "office", "mein", "workload", "zyada", "tha"],
    "labels": ["URD", "ENG", "URD", "ENG", "URD", "URD"]
},
{
    "sentence": "Laptop ki battery low hai",
    "words": ["Laptop", "ki", "battery", "low", "hai"],
    "labels": ["ENG", "URD", "ENG", "ENG", "URD"]
},
{
    "sentence": "Yaar coffee peene chalte hain",
    "words": ["Yaar", "coffee", "peene", "chalte", "hain"],
    "labels": ["URD", "ENG", "URD", "URD", "URD"]
},
    {
    "sentence": "Kal online class bohot interesting thi",
    "words": ["Kal", "online", "class", "bohot", "interesting", "thi"],
    "labels": ["URD", "ENG", "ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Mujhe assignment ki deadline yaad nahi thi",
    "words": ["Mujhe", "assignment", "ki", "deadline", "yaad", "nahi", "thi"],
    "labels": ["URD", "ENG", "URD", "ENG", "URD", "URD", "URD"]
},
{
    "sentence": "Teacher ne feedback send kar diya",
    "words": ["Teacher", "ne", "feedback", "send", "kar", "diya"],
    "labels": ["ENG", "URD", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Aaj meeting ka time change hogaya",
    "words": ["Aaj", "meeting", "ka", "time", "change", "hogaya"],
    "labels": ["URD", "ENG", "URD", "ENG", "ENG", "URD"]
},
{
    "sentence": "Presentation ke slides ready hain",
    "words": ["Presentation", "ke", "slides", "ready", "hain"],
    "labels": ["ENG", "URD", "ENG", "ENG", "URD"]
},
{
    "sentence": "Internet connection phir disconnect hogaya",
    "words": ["Internet", "connection", "phir", "disconnect", "hogaya"],
    "labels": ["ENG", "ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Yaar movie ka ending bohot emotional tha",
    "words": ["Yaar", "movie", "ka", "ending", "bohot", "emotional", "tha"],
    "labels": ["URD", "ENG", "URD", "ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Meri coding practice improve horhi hai",
    "words": ["Meri", "coding", "practice", "improve", "horhi", "hai"],
    "labels": ["URD", "ENG", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Please document upload kar dena",
    "words": ["Please", "document", "upload", "kar", "dena"],
    "labels": ["ENG", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Exam ke baad picnic plan karte hain",
    "words": ["Exam", "ke", "baad", "picnic", "plan", "karte", "hain"],
    "labels": ["ENG", "URD", "URD", "ENG", "ENG", "URD", "URD"]
},
    {
    "sentence": "Kal client meeting bohot productive thi",
    "words": ["Kal", "client", "meeting", "bohot", "productive", "thi"],
    "labels": ["URD", "ENG", "ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Mujhe email ka reply abhi dena hai",
    "words": ["Mujhe", "email", "ka", "reply", "abhi", "dena", "hai"],
    "labels": ["URD", "ENG", "URD", "ENG", "URD", "URD", "URD"]
},
{
    "sentence": "Aaj lecture bohot informative tha",
    "words": ["Aaj", "lecture", "bohot", "informative", "tha"],
    "labels": ["URD", "ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Mera internet package expire hogaya",
    "words": ["Mera", "internet", "package", "expire", "hogaya"],
    "labels": ["URD", "ENG", "ENG", "ENG", "URD"]
},
{
    "sentence": "Assignment submit karne ka last chance hai",
    "words": ["Assignment", "submit", "karne", "ka", "last", "chance", "hai"],
    "labels": ["ENG", "ENG", "URD", "URD", "ENG", "ENG", "URD"]
},
{
    "sentence": "Please camera on kar lo",
    "words": ["Please", "camera", "on", "kar", "lo"],
    "labels": ["ENG", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Mujhe new project bohot pasand aya",
    "words": ["Mujhe", "new", "project", "bohot", "pasand", "aya"],
    "labels": ["URD", "ENG", "ENG", "URD", "URD", "URD"]
},
{
    "sentence": "Ye software update karna zaroori hai",
    "words": ["Ye", "software", "update", "karna", "zaroori", "hai"],
    "labels": ["URD", "ENG", "ENG", "URD", "URD", "URD"]
},
{
    "sentence": "Office se call ayi thi",
    "words": ["Office", "se", "call", "ayi", "thi"],
    "labels": ["ENG", "URD", "ENG", "URD", "URD"]
},
{
    "sentence": "Weekend par shopping ka plan hai",
    "words": ["Weekend", "par", "shopping", "ka", "plan", "hai"],
    "labels": ["ENG", "URD", "ENG", "URD", "ENG", "URD"]
},
    {
    "sentence": "Mera assignment finally complete hogaya",
    "words": ["Mera", "assignment", "finally", "complete", "hogaya"],
    "labels": ["URD", "ENG", "ENG", "ENG", "URD"]
},
{
    "sentence": "Please attendance sheet upload kar do",
    "words": ["Please", "attendance", "sheet", "upload", "kar", "do"],
    "labels": ["ENG", "ENG", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Kal interview ka result ayega",
    "words": ["Kal", "interview", "ka", "result", "ayega"],
    "labels": ["URD", "ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Yeh mobile update ke baad fast hogaya",
    "words": ["Yeh", "mobile", "update", "ke", "baad", "fast", "hogaya"],
    "labels": ["URD", "ENG", "ENG", "URD", "URD", "ENG", "URD"]
},
{
    "sentence": "Aaj Zoom class cancel hogayi",
    "words": ["Aaj", "Zoom", "class", "cancel", "hogayi"],
    "labels": ["URD", "ENG", "ENG", "ENG", "URD"]
},
{
    "sentence": "Teacher ne marks portal par upload kiye",
    "words": ["Teacher", "ne", "marks", "portal", "par", "upload", "kiye"],
    "labels": ["ENG", "URD", "ENG", "ENG", "URD", "ENG", "URD"]
},
{
    "sentence": "Mujhe assignment print karwana hai",
    "words": ["Mujhe", "assignment", "print", "karwana", "hai"],
    "labels": ["URD", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Office ka network down tha",
    "words": ["Office", "ka", "network", "down", "tha"],
    "labels": ["ENG", "URD", "ENG", "ENG", "URD"]
},
{
    "sentence": "Yaar WhatsApp group mute kar do",
    "words": ["Yaar", "WhatsApp", "group", "mute", "kar", "do"],
    "labels": ["URD", "ENG", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Meri presentation sab ko pasand ayi",
    "words": ["Meri", "presentation", "sab", "ko", "pasand", "ayi"],
    "labels": ["URD", "ENG", "URD", "URD", "URD", "URD"]
},
    {
    "sentence": "Kal workshop attend karni hai",
    "words": ["Kal", "workshop", "attend", "karni", "hai"],
    "labels": ["URD", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Mera phone silent mode par tha",
    "words": ["Mera", "phone", "silent", "mode", "par", "tha"],
    "labels": ["URD", "ENG", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Please file download kar lo",
    "words": ["Please", "file", "download", "kar", "lo"],
    "labels": ["ENG", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Yeh project bohot interesting lag raha hai",
    "words": ["Yeh", "project", "bohot", "interesting", "lag", "raha", "hai"],
    "labels": ["URD", "ENG", "URD", "ENG", "URD", "URD", "URD"]
},
{
    "sentence": "Manager ne meeting postpone kar di",
    "words": ["Manager", "ne", "meeting", "postpone", "kar", "di"],
    "labels": ["ENG", "URD", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Mujhe login password yaad nahi",
    "words": ["Mujhe", "login", "password", "yaad", "nahi"],
    "labels": ["URD", "ENG", "ENG", "URD", "URD"]
},
{
    "sentence": "Assignment ka feedback mil gaya",
    "words": ["Assignment", "ka", "feedback", "mil", "gaya"],
    "labels": ["ENG", "URD", "ENG", "URD", "URD"]
},
{
    "sentence": "Aaj cafeteria mein lunch bohot acha tha",
    "words": ["Aaj", "cafeteria", "mein", "lunch", "bohot", "acha", "tha"],
    "labels": ["URD", "ENG", "URD", "ENG", "URD", "URD", "URD"]
},
{
    "sentence": "Internet speed aj bohot slow hai",
    "words": ["Internet", "speed", "aj", "bohot", "slow", "hai"],
    "labels": ["ENG", "ENG", "URD", "URD", "ENG", "URD"]
},
{
    "sentence": "Kal university ka event attend karenge",
    "words": ["Kal", "university", "ka", "event", "attend", "karenge"],
    "labels": ["URD", "ENG", "URD", "ENG", "ENG", "URD"]
},
    {
    "sentence": "Kal seminar attend karna zaroori hai",
    "words": ["Kal","seminar","attend","karna","zaroori","hai"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Mujhe certificate download karna hai",
    "words": ["Mujhe","certificate","download","karna","hai"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Yaar system restart kar lo",
    "words": ["Yaar","system","restart","kar","lo"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Teacher ne online quiz announce ki",
    "words": ["Teacher","ne","online","quiz","announce","ki"],
    "labels": ["ENG","URD","ENG","ENG","ENG","URD"]
},
{
    "sentence": "Mera internet ab stable hai",
    "words": ["Mera","internet","ab","stable","hai"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Presentation ka topic finalize hogaya",
    "words": ["Presentation","ka","topic","finalize","hogaya"],
    "labels": ["ENG","URD","ENG","ENG","URD"]
},
{
    "sentence": "Please report email kar dena",
    "words": ["Please","report","email","kar","dena"],
    "labels": ["ENG","ENG","ENG","URD","URD"]
},
{
    "sentence": "Aaj library mein bohot rush tha",
    "words": ["Aaj","library","mein","bohot","rush","tha"],
    "labels": ["URD","ENG","URD","URD","ENG","URD"]
},
{
    "sentence": "Meeting ka link share kar do",
    "words": ["Meeting","ka","link","share","kar","do"],
    "labels": ["ENG","URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Laptop ka charger mil gaya",
    "words": ["Laptop","ka","charger","mil","gaya"],
    "labels": ["ENG","URD","ENG","URD","URD"]
},
{
    "sentence": "Kal training session bohot useful tha",
    "words": ["Kal","training","session","bohot","useful","tha"],
    "labels": ["URD","ENG","ENG","URD","ENG","URD"]
},
{
    "sentence": "Meri profile update hogayi",
    "words": ["Meri","profile","update","hogayi"],
    "labels": ["URD","ENG","ENG","URD"]
},
{
    "sentence": "Office ka printer work nahi kar raha",
    "words": ["Office","ka","printer","work","nahi","kar","raha"],
    "labels": ["ENG","URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Assignment ka format change hua",
    "words": ["Assignment","ka","format","change","hua"],
    "labels": ["ENG","URD","ENG","ENG","URD"]
},
{
    "sentence": "Please document verify kar lo",
    "words": ["Please","document","verify","kar","lo"],
    "labels": ["ENG","ENG","ENG","URD","URD"]
},
{
    "sentence": "Aaj meeting bohot late start hui",
    "words": ["Aaj","meeting","bohot","late","start","hui"],
    "labels": ["URD","ENG","URD","ENG","ENG","URD"]
},
{
    "sentence": "Mujhe Zoom link receive hogaya",
    "words": ["Mujhe","Zoom","link","receive","hogaya"],
    "labels": ["URD","ENG","ENG","ENG","URD"]
},
{
    "sentence": "Result ki notification agayi",
    "words": ["Result","ki","notification","agayi"],
    "labels": ["ENG","URD","ENG","URD"]
},
{
    "sentence": "Yeh software install karna easy hai",
    "words": ["Yeh","software","install","karna","easy","hai"],
    "labels": ["URD","ENG","ENG","URD","ENG","URD"]
},
{
    "sentence": "Kal office se jaldi nikalna hai",
    "words": ["Kal","office","se","jaldi","nikalna","hai"],
    "labels": ["URD","ENG","URD","URD","URD","URD"]
},
    {
    "sentence": "Mera browser crash hogaya achanak",
    "words": ["Mera","browser","crash","hogaya","achanak"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Please meeting reschedule kar do",
    "words": ["Please","meeting","reschedule","kar","do"],
    "labels": ["ENG","ENG","ENG","URD","URD"]
},
{
    "sentence": "Aaj class ka timing change hua",
    "words": ["Aaj","class","ka","timing","change","hua"],
    "labels": ["URD","ENG","URD","ENG","ENG","URD"]
},
{
    "sentence": "Mujhe internship ka update mila",
    "words": ["Mujhe","internship","ka","update","mila"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Teacher ne attendance upload kar di",
    "words": ["Teacher","ne","attendance","upload","kar","di"],
    "labels": ["ENG","URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Yaar network issue phir agaya",
    "words": ["Yaar","network","issue","phir","agaya"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Presentation ka design bohot clean tha",
    "words": ["Presentation","ka","design","bohot","clean","tha"],
    "labels": ["ENG","URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Kal assignment print karwana hai",
    "words": ["Kal","assignment","print","karwana","hai"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Office ki meeting start hogayi",
    "words": ["Office","ki","meeting","start","hogayi"],
    "labels": ["ENG","URD","ENG","ENG","URD"]
},
{
    "sentence": "Please mobile silent kar lo",
    "words": ["Please","mobile","silent","kar","lo"],
    "labels": ["ENG","ENG","ENG","URD","URD"]
},
{
    "sentence": "Aaj coding practice bohot productive thi",
    "words": ["Aaj","coding","practice","bohot","productive","thi"],
    "labels": ["URD","ENG","ENG","URD","ENG","URD"]
},
{
    "sentence": "Meri profile complete hogayi",
    "words": ["Meri","profile","complete","hogayi"],
    "labels": ["URD","ENG","ENG","URD"]
},
{
    "sentence": "Kal workshop ka certificate milega",
    "words": ["Kal","workshop","ka","certificate","milega"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Zoom meeting ka reminder agaya",
    "words": ["Zoom","meeting","ka","reminder","agaya"],
    "labels": ["ENG","ENG","URD","ENG","URD"]
},
{
    "sentence": "Assignment submit karne ka time khatam hua",
    "words": ["Assignment","submit","karne","ka","time","khatam","hua"],
    "labels": ["ENG","ENG","URD","URD","ENG","URD","URD"]
},
{
    "sentence": "Mujhe laptop repair karwana hai",
    "words": ["Mujhe","laptop","repair","karwana","hai"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Aaj office mein new manager aya",
    "words": ["Aaj","office","mein","new","manager","aya"],
    "labels": ["URD","ENG","URD","ENG","ENG","URD"]
},
{
    "sentence": "Please folder upload kar dena",
    "words": ["Please","folder","upload","kar","dena"],
    "labels": ["ENG","ENG","ENG","URD","URD"]
},
{
    "sentence": "Kal project demo bohot successful tha",
    "words": ["Kal","project","demo","bohot","successful","tha"],
    "labels": ["URD","ENG","ENG","URD","ENG","URD"]
},
{
    "sentence": "Internet connection ab theek chal raha hai",
    "words": ["Internet","connection","ab","theek","chal","raha","hai"],
    "labels": ["ENG","ENG","URD","URD","URD","URD","URD"]
},
    {
    "sentence": "Kal final presentation submit karni hai",
    "words": ["Kal","final","presentation","submit","karni","hai"],
    "labels": ["URD","ENG","ENG","ENG","URD","URD"]
},
{
    "sentence": "Mera account login nahi horha",
    "words": ["Mera","account","login","nahi","horha"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Please assignment email kar dena",
    "words": ["Please","assignment","email","kar","dena"],
    "labels": ["ENG","ENG","ENG","URD","URD"]
},
{
    "sentence": "Teacher ne project approve kar diya",
    "words": ["Teacher","ne","project","approve","kar","diya"],
    "labels": ["ENG","URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Mujhe internship certificate mil gaya",
    "words": ["Mujhe","internship","certificate","mil","gaya"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Aaj workshop bohot informative thi",
    "words": ["Aaj","workshop","bohot","informative","thi"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Office ka server down tha",
    "words": ["Office","ka","server","down","tha"],
    "labels": ["ENG","URD","ENG","ENG","URD"]
},
{
    "sentence": "Zoom class ka recording upload hogaya",
    "words": ["Zoom","class","ka","recording","upload","hogaya"],
    "labels": ["ENG","ENG","URD","ENG","ENG","URD"]
}
]

# %%
rows = []

for entry in data:
    for word, label in zip(entry["words"], entry["labels"]):
        rows.append({
            "sentence": entry["sentence"],
            "word": word,
            "label": label
        })

df = pd.DataFrame(rows)

df.to_csv("dataset.csv", index=False, encoding="utf-8")

print(f"Dataset created: {len(df)} word entries")
print(f"Sentences: {df.sentence.nunique()}")
print(df.head())
# Out:
# Dataset created: 862 word entries
# Sentences: 150
#                     sentence   word label
# 0  Aaj ka din bohot busy tha    Aaj   URD
# 1  Aaj ka din bohot busy tha     ka   URD
# 2  Aaj ka din bohot busy tha    din   URD
# 3  Aaj ka din bohot busy tha  bohot   URD
# 4  Aaj ka din bohot busy tha   busy   ENG

# %%
from google.colab import files
files.download("dataset.csv")
